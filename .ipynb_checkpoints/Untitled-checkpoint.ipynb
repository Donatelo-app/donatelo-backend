# %%
from PIL import Image

# %%
res = {
    "background": Image.open("cat.png"),
    "cat_progress:progress": Image.open("cat-progress.png")
}

# %%
import render

# %%
render.render_cover([], res, {})
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=795x200 at 0x619B770>

# %%
text = {"id": "super_text",
      "type": "text",
      "value": "Hello world",
      "x": 420,
      "y": 30,
      "size":60,
      "font": "BEBAS", 
      "angle": 0.0,
      "color": "#E5E5E5FF",
      }

# %%
res = {
    "background": Image.open("cat.png"),
    "cat_progress:progress": Image.open("cat-progress.png")
}
c = render.render_cover([text], res, {})
c
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=795x200 at 0x64B7DF0>

# %%
render.draw_text("HELLO", "ROBOTO", 300, color_code="#FFFFFFFF")
# Out:
# <PIL.Image.Image image mode=RGBA size=913x282 at 0x619B3D0>

# %%
from PIL import ImageFont, ImageDraw, ImageColor
font = ImageFont.truetype('./render/fonts/%s' % "Roboto-Regular.ttf", 50)

# %%
color = ImageColor.getrgb("#FFFFFFFF")
ImageDraw.Draw(c).text((120, 0), "LOL KEK", font=font, color=color)

# %%
c
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=795x200 at 0x64B7DF0>

# %%
color = ImageColor.getrgb(color_code)
if len(color)==3: color = tuple(list(color) + [255])

font = font = ImageFont.truetype('./render/fonts/%s' % "Roboto-Regular.ttf", 50)

image = Image.new('RGBA', font.getsize(text)) 
ImageDraw.Draw(image).text((0, 0), text, font=font, fill=color)

return image
