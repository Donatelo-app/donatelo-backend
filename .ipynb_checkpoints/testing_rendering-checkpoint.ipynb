# %%
import render

# %%
from PIL import Image

# %%
a = Image.open("db2.png")

# %%
render.draw_radial(a, None, 0, 0, 53, direction=1)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x64D9710>

# %%
render.draw_progress_bar(a, None, 0, 50)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x64D9930>

# %%
text = render.draw_text("Hello world", "ROBOTO", size=50, color_code="#ffffff")
text
# Out:
# <PIL.Image.Image image mode=RGBA size=251x47 at 0x64D9BB0>

# %%
back = Image.open("oxxxymiron.png")
render.paste_image(text, back, (160,200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x364 at 0x578BE50>

# %%
from PIL import Image

# %%
text = {
    "id": "ew",
    "type": "text",
    "value": "Hello world!",
    "x": 160,
    "y": 200,
    "size": 50,
    "font": "ROBOTO",
    "angle": 30,
    "color": "#FFFFFF"
}

# %%
radial = {
      "id": "lel",
      "type": "linear",
      "start_angle": 0,
      "value": "some_value",
      "max_value": 70,
      "x": 300,
      "y": 120,
      "w": 150,
      "h": 400,
      "angle": 0,
      "border": 1
      }

# %%
back = Image.open("oxxxymiron.png")
img = Image.open("db2.png")

# %%
res = {
    'lel:bar': img,
    "background": back,
}

# %%
import render

# %%
render.render_cover([text, radial], res, {"total":200})
# Out:
# <PIL.Image.Image image mode=RGB size=1280x364 at 0x14EBF30>

# %%
import jinja2

# %%
jinja2.Template("text: {{total}}").render(**{"total":200, "nototal":"kek"})
# Out:
# 'text: 200'
