# %%
import render

# %%
from PIL import Image

# %%
back = Image.open("oxxxymiron.png")
render.paste_image(text, back, (0,0), align="center")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x364 at 0x54F2170>

# %%
from PIL import Image

# %%
text = {
    "id": "ew",
    "type": "text",
    "value": "Денег собрано: {{total}}",
    "x": 0,
    "y": -154,
    "size": 50,
    "font": "ROBOTO",
    "angle": 0,
    "color": "#FFFFFF"
}

# %%
radial = {
      "id": "lel",
      "type": "linear",
      "start_angle": 0,
      "value": "total",
      "max_value": 120,
      "x": 300,
      "y": 120,
      "w": 150,
      "h": 400,
      "angle": 0,
      "border": 1
      }

# %%
back = Image.open("oxxxymiron.png")
img = Image.open("db2.png")

# %%
res = {
    'lel:bar': img,
    "background": back,
}

# %%
import render

# %%
render.render_cover([text], res, {"total":90})
# Out:
# <PIL.Image.Image image mode=RGB size=1280x364 at 0x5FED770>
